# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import math

# %%
sent_score= pd.read_csv('C:/Dissertation/Datasets/sumscore2.csv')

# %%
sent_score['Sentiment_Direction'] = np.where(sent_score['FinalScore'] > sent_score['FinalScore'].shift(1), 'Up', 'Down')
sent_score['PercentageDifference'] = (sent_score['FinalScore'] - sent_score['FinalScore'].shift(1)) / abs(sent_score['FinalScore']) * 100
sent_score['PercentageDifference'].iloc[0] = float('NaN')
# Out:
# C:\Users\felix\AppData\Local\Temp\ipykernel_2520\2398520983.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_score['PercentageDifference'].iloc[0] = float('NaN')

# %%
sent_score
# Out:
#     Unnamed: 0        Date  FinalScore Sentiment_Direction  \
# 0            0  27-02-2023  -56.298266                Down
# 1            1  28-02-2023  -58.008373                Down
# 2            2  01-03-2023  -77.803071                Down
# 3            3  02-03-2023  -76.579328                  Up
# 4            4  03-03-2023  -73.377458                  Up
# ..         ...         ...         ...                 ...
# 89          89  27-05-2023  -66.212404                  Up
# 90          90  28-05-2023  -40.889290                  Up
# 91          91  29-05-2023  -44.392002                Down
# 92          92  30-05-2023  -63.050229                Down
# 93          93  31-05-2023  -81.507414                Down
#
#     PercentageDifference
# 0                    NaN
# 1              -2.948035
# 2             -25.442052
# 3               1.598007
# 4               4.363560
# ..                   ...
# 89             40.952761
# 90             61.930922
# ...

# %%
#Prediction for May 30th
may_31st_data = sent_score[sent_score['Date'] == '29-05-2023']

sent_direction = may_31st_data['Sentiment_Direction'].iloc[0]
percentage_difference = may_31st_data['PercentageDifference'].iloc[0]
date= may_31st_data['Date'].iloc[0]

# %%
sent_score
# Out:
#     Unnamed: 0        Date  FinalScore Sentiment_Direction  \
# 0            0  27-02-2023  -56.298266                Down
# 1            1  28-02-2023  -58.008373                Down
# 2            2  01-03-2023  -77.803071                Down
# 3            3  02-03-2023  -76.579328                  Up
# 4            4  03-03-2023  -73.377458                  Up
# ..         ...         ...         ...                 ...
# 89          89  27-05-2023  -66.212404                  Up
# 90          90  28-05-2023  -40.889290                  Up
# 91          91  29-05-2023  -44.392002                Down
# 92          92  30-05-2023  -63.050229                Down
# 93          93  31-05-2023  -81.507414                Down
#
#     PercentageDifference
# 0                    NaN
# 1              -2.948035
# 2             -25.442052
# 3               1.598007
# 4               4.363560
# ..                   ...
# 89             40.952761
# 90             61.930922
# ...

# %%
date= "30-05-2023"

# %%
formatted_value_sent = "{:.2f}%".format(percentage_difference)

# %%
btc_price= pd.read_csv("C:/Dissertation/ML Codes Final/ML Output/bitcoin_op.csv")

# %%
btc_price['PercentageDifference'] = (btc_price['Predicted_Bitcoin_Price'] - btc_price['Predicted_Bitcoin_Price'].shift(1)) / abs(btc_price['Predicted_Bitcoin_Price']) * 100
btc_price['PercentageDifference'].iloc[0] = float('NaN')
data= btc_price['Predicted_Bitcoin_Price']
sample_size = len(data)
standard_deviation = np.std(data)
standard_error = standard_deviation / np.sqrt(sample_size)

z = stats.norm.ppf(1 - (1 - 0.95) / 2)

may_31st_data = btc_price[btc_price['Date'] == '2023-05-30']

lower_bound_b = round(may_31st_data['Predicted_Bitcoin_Price'].iloc[0] - z * standard_error,1)

upper_bound_b = round(may_31st_data['Predicted_Bitcoin_Price'].iloc[0] + z * standard_error,1)


btc_direction = may_31st_data['Predicted_Direction'].iloc[0]
percentage_difference = may_31st_data['PercentageDifference'].iloc[0]
formatted_value_btc = "{:.2f}%".format(percentage_difference)
predicted_price_btc= may_31st_data['Predicted_Bitcoin_Price'].iloc[0]
date= may_31st_data['Date'].iloc[0]
# Out:
# C:\Users\felix\AppData\Local\Temp\ipykernel_2520\1069773531.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   btc_price['PercentageDifference'].iloc[0] = float('NaN')

# %%
eth_price= pd.read_csv("C:/Dissertation/ML Codes Final/ML Output/etherum_op.csv")

# %%
eth_price['PercentageDifference'] = (eth_price['Predicted_Etherum_Price'] - eth_price['Predicted_Etherum_Price'].shift(1)) / abs(eth_price['Predicted_Etherum_Price']) * 100
eth_price['PercentageDifference'].iloc[0] = float('NaN')
data= eth_price['Predicted_Etherum_Price']
sample_size = len(data)
standard_deviation = np.std(data)
standard_error = standard_deviation / np.sqrt(sample_size)

z = stats.norm.ppf(1 - (1 - 0.95) / 2)

may_31st_data = eth_price[eth_price['Date'] == '2023-05-30']
lower_bound_e = round(may_31st_data['Predicted_Etherum_Price'].iloc[0] - z * standard_error,1)
upper_bound_e = round(may_31st_data['Predicted_Etherum_Price'].iloc[0] + z * standard_error,1)



eth_direction = may_31st_data['Predicted_Direction'].iloc[0]
percentage_difference = may_31st_data['PercentageDifference'].iloc[0]
formatted_value_eth = "{:.2f}%".format(percentage_difference)
predicted_price_eth= may_31st_data['Predicted_Etherum_Price'].iloc[0]
date= may_31st_data['Date'].iloc[0]
# Out:
# C:\Users\felix\AppData\Local\Temp\ipykernel_2520\3019003406.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eth_price['PercentageDifference'].iloc[0] = float('NaN')

# %%
xrp_price= pd.read_csv("C:/Dissertation/ML Codes Final/ML Output/xrp_SVR.csv")

# %%
xrp_price['PercentageDifference'] = (xrp_price['Predicted_Ripple_Price'] - xrp_price['Predicted_Ripple_Price'].shift(1)) / abs(xrp_price['Predicted_Ripple_Price']) * 100
xrp_price['PercentageDifference'].iloc[0] = float('NaN')
data= xrp_price['Predicted_Ripple_Price']
sample_size = len(data)
standard_deviation = np.std(data)
standard_error = standard_deviation / np.sqrt(sample_size)

z = stats.norm.ppf(1 - (1 - 0.95) / 2)

may_31st_data = xrp_price[xrp_price['Date'] == '2023-05-30']

lower_bound_x = round(may_31st_data['Predicted_Ripple_Price'].iloc[0] - z * standard_error,2)
upper_bound_x = round(may_31st_data['Predicted_Ripple_Price'].iloc[0] + z * standard_error,2)



xrp_direction = may_31st_data['Predicted_Direction'].iloc[0]
percentage_difference = may_31st_data['PercentageDifference'].iloc[0]
formatted_value_xrp = "{:.2f}%".format(percentage_difference)
predicted_price_xrp= may_31st_data['Predicted_Ripple_Price'].iloc[0]
date= may_31st_data['Date'].iloc[0]
# Out:
# C:\Users\felix\AppData\Local\Temp\ipykernel_2520\1184881000.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xrp_price['PercentageDifference'].iloc[0] = float('NaN')

# %%
print(f"\033[1;30;47m MARKET SENTIMENT for", date, "\n")
if sent_direction== "Up":
    print (f"\033[1;32;47m Overall Crypto Market Sentiment is Up 😃", formatted_value_sent, "\n\n")
else:
    print (f"\033[1;31;47m Overall Crypto market Sentiment is Down 😟 by", formatted_value_sent, "\n\n")
    
print(f"\033[1;30;47m BITCOIN PRICE AND DIRECTION for",date," \n")
if btc_direction== "Up":
    print (f"\033[1;33;47m Overall Bitcoin Market Predicts Sell \n")
    print (f"\033[1;32;47m Overall Bitcoin Market Predicts an increase 😃:", "Exp. price:", predicted_price_btc, "by", formatted_value_btc,"in the range [",lower_bound_b, ":" ,upper_bound_b,"]", "\n\n")
else:
    print (f"\033[1;34;47m Overall Bitcoin Market Predicts Buy \n")
    print (f"\033[1;31;47m Overall Bitcoin Market Predicts an decrease 😟:", "Exp. price:", predicted_price_btc, "by", formatted_value_btc,"in the range [",lower_bound_b, ":" ,upper_bound_b,"]", "\n\n")
 

print(f"\033[1;30;47m ETHERUM PRICE AND DIRECTION for" ,date, "\n")
if eth_direction== "Up":
    print (f"\033[1;33;47m Overall Etherum Market Predicts Sell \n")
    print (f"\033[1;32;47m Overall Etherum Market Predicts an increase 😃:", "Exp. price:", predicted_price_eth, "by", formatted_value_eth,"in the range [",lower_bound_e, ":" ,upper_bound_e,"]", "\n\n")
else:
    print (f"\033[1;34;47m Overall Etherum Market Predicts Buy \n")
    print (f"\033[1;31;47m Overall Etherum Market Predicts an decrease 😟:", "Exp. price:", predicted_price_eth, "by", formatted_value_eth,"in the range [",lower_bound_e, ":" ,upper_bound_e,"]", "\n\n")  
    
print(f"\033[1;30;47m XRP PRICE AND DIRECTION for date \n")
if xrp_direction== "Up":
    print (f"\033[1;33;47m Overall Ripple Market Predicts Sell \n")
    print (f"\033[1;32;47m Overall Ripple Market Predicts an increase 😃:", "Exp. price:", predicted_price_xrp, "by", formatted_value_xrp,"in the range [",lower_bound_x, ":" ,upper_bound_x,"]", "\n\n") 
else:
    print (f"\033[1;34;47m Overall Ripple Market Predicts Buy \n")
    print (f"\033[1;31;47m Overall Ripple Market Predicts an decrease 😟:", "Exp. price:", predicted_price_xrp, "by", formatted_value_xrp,"in the range [",lower_bound_x, ":" ,upper_bound_x,"]", "\n\n")
# Out:
#  MARKET SENTIMENT for 2023-05-30
#
#  Overall Crypto market Sentiment is Down 😟 by -7.89%
#
#
#  BITCOIN PRICE AND DIRECTION for 2023-05-30
#
#  Overall Bitcoin Market Predicts Sell
#
#  Overall Bitcoin Market Predicts an increase 😃: Exp. price: 27546.227 by 0.82% in the range [ 27088.7 : 28003.8 ]
#
#
#  ETHERUM PRICE AND DIRECTION for 2023-05-30
#
#  Overall Etherum Market Predicts Sell
#
#  Overall Etherum Market Predicts an increase 😃: Exp. price: 1858.7549 by 0.76% in the range [ 1842.6 : 1875.0 ]
#
#
#  XRP PRICE AND DIRECTION for date
#
#  Overall Ripple Market Predicts Sell
#
#  Overall Ripple Market Predicts an increase 😃: Exp. price: 0.500729244385644 by 2.88% in the range [ 0.49 : 0.51 ]

# %%
import io
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
output_stream = io.StringIO()

print(f"MARKET SENTIMENT for",date, file=output_stream)
if sent_direction== "Up":
    print (f" Overall Crypto Market Sentiment is Up 😃 by ", formatted_value_sent, file=output_stream)
else:
    print (f" Overall Crypto market Sentiment is Down 😟 by ", formatted_value_sent, file=output_stream)
    
print(file=output_stream)
    
print(f"BITCOIN PRICE AND DIRECTION for " ,date,  file=output_stream)
if btc_direction== "Up":
    print (f" Overall Bitcoin Market Predicts Sell " ,  file=output_stream)
    print (f" Overall Bitcoin Market Predicts an increase 😃:", "Exp. price:", predicted_price_btc, "by", formatted_value_btc," in the price range [",lower_bound_b, ":" ,upper_bound_b," ]" "\n\n", file=output_stream)
else: 
    print (f" Overall Bitcoin Market Predicts Buy " ,  file=output_stream)
    print (f" Overall Bitcoin Market Predicts an decrease 😟:", "Exp. price:",predicted_price_btc,"by", formatted_value_btc," in the range [",lower_bound_b, ":" ,upper_bound_b," ]" "\n\n", file=output_stream)
    
print(file=output_stream)
    
print(f"ETHERUM PRICE AND DIRECTION for" , date,  file=output_stream)
if eth_direction== "Up":
    print (f" Overall Etherum Market Predicts Sell " ,  file=output_stream)
    print (f" Overall Etherum Market Predicts an increase 😃:", "Exp. price:",predicted_price_eth,"by", formatted_value_eth," in the range [",lower_bound_e, ":" ,upper_bound_e,"]" "\n\n", file=output_stream)
else: 
    print (f" Overall Etherum Market Predicts Buy " ,  file=output_stream)
    print (f" Overall Etherum Market Predicts an decrease 😟:", "Exp. price:",predicted_price_eth,"by", formatted_value_eth," in the range [",lower_bound_e, ":" ,upper_bound_e,"]" "\n\n", file=output_stream)
    
print(file=output_stream) 
    
print(f"XRP PRICE AND DIRECTION " ,  file=output_stream)
if xrp_direction== "Up":
    print (f" Overall Ripple Market Predicts Sell " ,  file=output_stream)
    print (f" Overall Ripple Market Predicts an increase 😃 by:", "Exp. price:",predicted_price_xrp,"by", formatted_value_xrp," in the range [",lower_bound_x, ":" ,upper_bound_x,"]" "\n\n", file=output_stream)
else: 
    print (f" Overall Ripple Market Predicts Buy " , file=output_stream)
    print (f" Overall Ripple Market Predicts an decrease 😟 by:", "Exp. price:",predicted_price_xrp,"by", formatted_value_xrp," in the range [",lower_bound_x, ":" ,upper_bound_x,"]" "\n\n", file=output_stream)
    
print(file=output_stream)

# %%
output = output_stream.getvalue()

# %%
print(output)
# Out:
# MARKET SENTIMENT for 2023-05-30
#  Overall Crypto market Sentiment is Down 😟 by  -7.89%
#
# BITCOIN PRICE AND DIRECTION for  2023-05-30
#  Overall Bitcoin Market Predicts Sell
#  Overall Bitcoin Market Predicts an increase 😃: Exp. price: 27546.227 by 0.82%  in the price range [ 27088.7 : 28003.8  ]
#
#
#
# ETHERUM PRICE AND DIRECTION for 2023-05-30
#  Overall Etherum Market Predicts Sell
#  Overall Etherum Market Predicts an increase 😃: Exp. price: 1858.7549 by 0.76%  in the range [ 1842.6 : 1875.0 ]
#
#
#
# XRP PRICE AND DIRECTION
#  Overall Ripple Market Predicts Sell
#  Overall Ripple Market Predicts an increase 😃 by: Exp. price: 0.500729244385644 by 2.88%  in the range [ 0.49 : 0.51 ]

# %%
type(output)
# Out:
# str

# %%
import os
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText


# In[6]:


# Email configuration
SMTP_SERVER = 'smtp.gmail.com'
SMTP_PORT = 587
SENDER_EMAIL = 'felixjosekannai@gmail.com'
RECIPIENT_EMAIL = 'felixjosekannai@gmail.com'


# In[7]:


def send_email(subject, body):
    try:
        # Connect to the SMTP server
        server = smtplib.SMTP(SMTP_SERVER, SMTP_PORT)
        server.starttls()

        # Log in to your email account using environment variables
        email_password = ''
        server.login(SENDER_EMAIL, email_password)

        # Create a multipart message container
        msg = MIMEMultipart()
        msg['From'] = SENDER_EMAIL
        msg['To'] = RECIPIENT_EMAIL
        msg['Subject'] = subject

        # Add message body
        msg.attach(MIMEText(body, 'plain'))

        # Send the email
        server.send_message(msg)

        # Disconnect from the server
        server.quit()
        print('Email sent successfully!')
    except Exception as e:
        print('Error sending email:', str(e))


# In[8]:


# Example usage
subject = 'Daily Cryptocurrency Analysis and Prediction Report for 2023-05-30'


body = f'''
Dear [Manager's Name],

I hope this email finds you well. As part of our ongoing project to predict cryptocurrency price movements, I have generated the following outputs:

{output}



Please let me know if you need any further information.

Best regards,
[Your Name]
'''


# In[9]:


send_email(subject, body)
# Out:
# Email sent successfully!
